# %%
import pandas as pd

# %%
df = pd.DataFrame()
df = pd.read_csv('sales_data.csv')
df.head()
# Out:
#   Region Manager Salesman  Sales
# 0  North      M1    Alice   1200
# 1  North      M1      Bob   1800
# 2  South      M2    Carol   1500
# 3   East      M3    David   2200
# 4   East      M3      Eva   1700
